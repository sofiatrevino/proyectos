# %% [markdown]
# # Examen Final  de Sofía Alicia Treviño Garza
#
# # Tema: Mortalidad Materna
#
# ## En el presente documento se explica de manera clara y concisa el análisis de los datos referidos acerca del tema de Mortalidad Materna, este análisis busca mostrar datos significativos referentes a las variables relacionadas con la tasa de Mortalidad Materna.
#
# ## En este documento se explica también como se abordo el análisis y los pasos que se siguieron para solucionarlo utilizando el Python como lenguaje de programación para generar los arreglos de datos y las gráficas que aquí se muestran.

# %% [markdown]
# # Algoritmo a seguir
# ##  1) Cargar los datos que vamos a observar en un arreglo
# ##  2) Imprimir y observar los datos del arreglo
# ##  3) Realizar limpiado de datos para un análisis inicial y seleccionar las preguntas con que abordaremos el análisis de variables
# ##  4) Seleccionar las variables y observarlas por medio de un arreglo de datos
# ##  5) Imprimir y mostrar las variables y sacar conclusiones de los datos
# ##  6) Generar gráficas significativas para explicar las conclusiones de los datos

# %% [markdown]
# # Paso 1: Trabajando con la Base de datos del archivo mortalidad.cvs

# %%
# Antes de iniciar a leer el archivo preparamos el Python para las librerías a utilizar durante el programa
# IMPORTAR LIBRERIAS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
## Ahora vamos a cargar los datos del archivo de mortalidad.cvs en un arreglo para tenerlos disponibles durante el programa
## Para cargar el archivo usamos el comando read_csv 
## El arreglo de datos se llamará Datosmortalidad

Datosmortalidad=pd.read_csv('C:\Anaconda\proyectos\mortalidad.csv')

# %%
# Vamos a imprimir los datos en pantalla para corroborar que se cargaron en el arreglo
Datosmortalidad
# Out:
#        Año de nacimiento  Mes de nacimiento Descripción del mes de nacimiento  \
# 0                   1972                  6                             JUNIO
# 1                   1967                  2                           FEBRERO
# 2                   1973                  6                             JUNIO
# 3                   1966                  1                             ENERO
# 4                   1975                  0                   NO ESPECIFICADO
# 5                   1975                  0                   NO ESPECIFICADO
# 6                   1985                  0                   NO ESPECIFICADO
# 7                   1978                  7                             JULIO
# 8                   1958                  9                        SEPTIEMBRE
# 9                   1970                  5                              MAYO
# 10                  1972                  4                             ABRIL
# ...

# %% [markdown]
# # Paso 2: Vamos a Imprimir y observar los datos del arreglo

# %%
## Con la instruccion head vamos a desplegar los encabezados del arreglo Datosmortalidad 
Datosmortalidad.head()
# Out:
#    Año de nacimiento  Mes de nacimiento Descripción del mes de nacimiento  \
# 0               1972                  6                             JUNIO
# 1               1967                  2                           FEBRERO
# 2               1973                  6                             JUNIO
# 3               1966                  1                             ENERO
# 4               1975                  0                   NO ESPECIFICADO
#
#    Día de nacimiento  Genero Clave de la edad  Edad cumplida  Estado conyugal  \
# 0                 25       2                A             29                5
# 1                  1       2                A             35                5
# 2                 21       2                A             29                5
# 3                 23       2                A             36                5
# 4                  0       2                A             30                5
#
# ...

# %% [markdown]
# # Paso 3: Realizar limpiado de datos para un análisis inicial y seleccionar las preguntas con que abordaremos el análisis de variables

# %%
## Vamos a ver primero cuantas razones existen para que se presente la mortalidad
## Para esto veamos el campo de Descrición de la razón de mortalidad materna
Datosmortalidad['Descrición de la razón de mortalidad materna'].unique()
# Out:
# array(['Muertes Maternas para la razón de Mortalidad Materna',
#        'Muertes Maternas excluidas para la razón de Mortalidad Materna'],
#       dtype=object)

# %%
# Esta información nos muestra que dentro de las razones de Mortalidad aparecen algunos datos que son exluidos, es decir
# que no son necesarios considerar para el análisis porque la razón de mortalidad podría deberse a otra causa diferente a la
# cuestion de maternidad

len(Datosmortalidad['Descrición de la razón de mortalidad materna'].unique())
# Out:
# 2

# %%
# Algo interesante a considerar es de que estado civil son las personas que se consideraron en la muestra
# para esto vamos a ver el campo de Descripción del estado conyugal

# Con la instruccion len contemos cuantos diferentes estados conyugales se consideraron
len(Datosmortalidad['Descripción del estado conyugal'].unique())
# Out:
# 8

# %%
## Vemos que hay 8 estados conyugales distintos y veamos cuales son
Datosmortalidad['Descripción del estado conyugal'].unique()
# Out:
# array(['CASADO', 'SE IGNORA', 'SEPARADO', 'DIVORCIADO', 'UNION LIBRE',
#        'SOLTERO', 'VIUDO', 'NO APLICA A MENORES DE 12 AÑOS'], dtype=object)

# %% [markdown]
# ## Como parte del paso 3 vamos a realizar una seleccion de campos para dejar solo las columnas requeridas para el análisis: Edad cumplida, Descripción del estado conyugal, Tamaño de localidad, Localidad de ocurrencia, Descrición de la localidad de ocurrencia

# %%
# Vamos a eliminar las columnas que no usaremos en el análisis
# Generar una copia de los datos para no afectar el arreglo original
# El arreglo de la copia se llama Seleccionadosmortalidad

Edadcumplida=Datosmortalidad.set_index('Edad cumplida')
Edadcumplida

##Seleccionadosmortalidad=Datosmortalidad.drop(['Año de nacimiento','Mes de nacimiento','Descripción del mes de nacimiento','Genero','Clave de la edad','Estado conyugal','Entidad de residencia'
                                              # 'Reference Period Code','Reference Period','Flag Codes','Flags'],axis=1)

A=[]
A(data = Edad, index = Datosmortalidad.columns, columns = ['Edad cumplida','Descripción del estado conyugal'])
    
#    'Edad cumplida', 
#    'Descripción del estado conyugal', 
#    'Tamaño de localidad', 
#    'Localidad de ocurrencia', 
#    'Descripción de la localidad de ocurrencia'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-1f03a69bf4cd> in <module>()
#      10
#      11 A=[]
# ---> 12 A(data = Edad, index = Datosmortalidad.columns, columns = ['Edad cumplida','Descripción del estado conyugal'])
#      13
#      14 #    'Edad cumplida',
#
# NameError: name 'Edad' is not defined

# %%
DatosOCDE
# Out:
#      LOCATION          Country INDICATOR  \
# 0         AUS        Australia   JE_LMIS
# 1         AUT          Austria   JE_LMIS
# 2         BEL          Belgium   JE_LMIS
# 3         CAN           Canada   JE_LMIS
# 4         CZE   Czech Republic   JE_LMIS
# 5         DNK          Denmark   JE_LMIS
# 6         FIN          Finland   JE_LMIS
# 7         FRA           France   JE_LMIS
# 8         DEU          Germany   JE_LMIS
# 9         GRC           Greece   JE_LMIS
# 10        HUN          Hungary   JE_LMIS
# 11        ISL          Iceland   JE_LMIS
# 12        IRL          Ireland   JE_LMIS
# 13        ITA            Italy   JE_LMIS
# 14        JPN            Japan   JE_LMIS
# 15        KOR            Korea   JE_LMIS
# 16        LUX       Luxembourg   JE_LMIS
# 17        MEX           Mexico   JE_LMIS
# 18        NLD      Netherlands   JE_LMIS
# 19        NZL      New Zealand   JE_LMIS
# 20        NOR           Norway   JE_LMIS
# 21        POL           Poland   JE_LMIS
# ...

# %%
# DatosOCDE.head() seria solo para ver los encabezados
# Esta es para poder ver la impresion completa de los datos
pd.DataFrame(DatosOCDE)
# Out:
#      LOCATION          Country INDICATOR  \
# 0         AUS        Australia   JE_LMIS
# 1         AUT          Austria   JE_LMIS
# 2         BEL          Belgium   JE_LMIS
# 3         CAN           Canada   JE_LMIS
# 4         CZE   Czech Republic   JE_LMIS
# 5         DNK          Denmark   JE_LMIS
# 6         FIN          Finland   JE_LMIS
# 7         FRA           France   JE_LMIS
# 8         DEU          Germany   JE_LMIS
# 9         GRC           Greece   JE_LMIS
# 10        HUN          Hungary   JE_LMIS
# 11        ISL          Iceland   JE_LMIS
# 12        IRL          Ireland   JE_LMIS
# 13        ITA            Italy   JE_LMIS
# 14        JPN            Japan   JE_LMIS
# 15        KOR            Korea   JE_LMIS
# 16        LUX       Luxembourg   JE_LMIS
# 17        MEX           Mexico   JE_LMIS
# 18        NLD      Netherlands   JE_LMIS
# 19        NZL      New Zealand   JE_LMIS
# 20        NOR           Norway   JE_LMIS
# 21        POL           Poland   JE_LMIS
# ...

# %%
# Cantidad de registros
len(DatosOCDE)
# Out:
# 3398

# %%
# Arreglo solo de los Paises que existen en la base de datos
Pais=DatosOCDE.set_index('Country')

# Veces que aparece MX Mexico en la Base de datos
len(Pais.loc['Mexico'])
# Out:
# 88

# %%
# Indicadores diferentes
DatosOCDE['Indicator'].unique()
# Out:
# array(['Labour market insecurity',
#        'Stakeholder engagement for developing regulations',
#        'Feeling safe walking alone at night',
#        'Dwellings without basic facilities', 'Housing expenditure',
#        'Rooms per person', 'Household net adjusted disposable income',
#        'Household net financial wealth', 'Employment rate',
#        'Long-term unemployment rate', 'Personal earnings',
#        'Quality of support network', 'Educational attainment',
#        'Student skills', 'Years in education', 'Air pollution',
#        'Water quality', 'Voter turnout', 'Life expectancy',
#        'Self-reported health', 'Life satisfaction', 'Homicide rate',
#        'Employees working very long hours',
#        'Time devoted to leisure and personal care'], dtype=object)

# %%
## Cosas interesantes que vemos en los datos y que vamos a analizar

## Cual es el nivel de inseguridad laboral 
## Cual es la calidad del soporte a la educacion 'Quality of support network'
## Cual es la relacion entre el soporte a la educacion y el nivel laboral


#Podemos publicar el valor de cada indicador en cada país
# Por ejemplo si tomamos el indicador 'Labour market insecurity'

IndicadorPais=DatosOCDE.set_index('Indicator')
pd.DataFrame(IndicadorPais)
# Out:
#                                           LOCATION          Country INDICATOR  \
# Indicator
# Labour market insecurity                       AUS        Australia   JE_LMIS
# Labour market insecurity                       AUT          Austria   JE_LMIS
# Labour market insecurity                       BEL          Belgium   JE_LMIS
# Labour market insecurity                       CAN           Canada   JE_LMIS
# Labour market insecurity                       CZE   Czech Republic   JE_LMIS
# Labour market insecurity                       DNK          Denmark   JE_LMIS
# Labour market insecurity                       FIN          Finland   JE_LMIS
# Labour market insecurity                       FRA           France   JE_LMIS
# Labour market insecurity                       DEU          Germany   JE_LMIS
# Labour market insecurity                       GRC           Greece   JE_LMIS
# Labour market insecurity                       HUN          Hungary   JE_LMIS
# ...

# %%
## Esto es para extraer solamente los datos de la Inseguridad en los paises
DatosInseguridad = DatosOCDE[DatosOCDE['Indicator'] == 'Labour market insecurity']
DatosInseguridad = DatosInseguridad[DatosInseguridad['Inequality'] == 'Total']

# %%
DatosInseguridad
MedirIndicador=DatosInseguridad.set_index('Indicator')
pd.DataFrame(MedirIndicador)
len(MedirIndicador.loc['Labour market insecurity'])
# Out:
# 39

# %%
# Datos de Inseguridad de todos los paises
DatosInseguridad
# Out:
#    LOCATION          Country INDICATOR                 Indicator Measure  \
# 0       AUS        Australia   JE_LMIS  Labour market insecurity   Value
# 1       AUT          Austria   JE_LMIS  Labour market insecurity   Value
# 2       BEL          Belgium   JE_LMIS  Labour market insecurity   Value
# 3       CAN           Canada   JE_LMIS  Labour market insecurity   Value
# 4       CZE   Czech Republic   JE_LMIS  Labour market insecurity   Value
# 5       DNK          Denmark   JE_LMIS  Labour market insecurity   Value
# 6       FIN          Finland   JE_LMIS  Labour market insecurity   Value
# 7       FRA           France   JE_LMIS  Labour market insecurity   Value
# 8       DEU          Germany   JE_LMIS  Labour market insecurity   Value
# 9       GRC           Greece   JE_LMIS  Labour market insecurity   Value
# 10      HUN          Hungary   JE_LMIS  Labour market insecurity   Value
# 11      ISL          Iceland   JE_LMIS  Labour market insecurity   Value
# ...

# %%
# Arreglo solo de los Paises que existen en la base de datos
Pais=DatosInseguridad.set_index('Country')

# Veces que aparece MX Mexico en la Base de datos
len(Pais.loc['Mexico'])
# Out:
# 7

# %%
DatosInseguridadMexico = DatosInseguridad[DatosInseguridad['LOCATION'] == 'MEX']

# %%
DatosInseguridadMexico
# Out:
#    LOCATION Country INDICATOR                 Indicator Measure Inequality  \
# 17      MEX  Mexico   JE_LMIS  Labour market insecurity   Value      Total
#
#           Unit  Value
# 17  Percentage    4.6

# %%
DatosInseguridad['Value'].plot(kind='line')
plt.xlabel('paises')
plt.ylabel('nivel de inseguridad laboral')
plt.title('Porcentaje de Inseguridad Laboral en cada país')
plt.show()

# %%
## Datos de la variable Calidad de Soporte a la educación

CalidadEducativa = DatosOCDE[DatosOCDE['Indicator'] == 'Quality of support network']
CalidadEducativa = CalidadEducativa[CalidadEducativa['Inequality'] == 'Total']
CalidadEducativa
# Out:
#      LOCATION          Country INDICATOR                   Indicator Measure  \
# 1509      AUS        Australia  SC_SNTWS  Quality of support network   Value
# 1510      AUT          Austria  SC_SNTWS  Quality of support network   Value
# 1511      BEL          Belgium  SC_SNTWS  Quality of support network   Value
# 1512      CAN           Canada  SC_SNTWS  Quality of support network   Value
# 1513      CZE   Czech Republic  SC_SNTWS  Quality of support network   Value
# 1514      DNK          Denmark  SC_SNTWS  Quality of support network   Value
# 1515      FIN          Finland  SC_SNTWS  Quality of support network   Value
# 1516      FRA           France  SC_SNTWS  Quality of support network   Value
# 1517      DEU          Germany  SC_SNTWS  Quality of support network   Value
# 1518      GRC           Greece  SC_SNTWS  Quality of support network   Value
# 1519      HUN          Hungary  SC_SNTWS  Quality of support network   Value
# ...

# %%
MedirIndicador=CalidadEducativa.set_index('Indicator')
pd.DataFrame(MedirIndicador)
len(MedirIndicador.loc['Quality of support network'])
# Out:
# 39

# %%
#Datos de Calidad educativa en Mexico
CalidadEducativaMexico = CalidadEducativa[CalidadEducativa['LOCATION'] == 'MEX']
CalidadEducativaMexico
# Out:
#      LOCATION Country INDICATOR                   Indicator Measure  \
# 1526      MEX  Mexico  SC_SNTWS  Quality of support network   Value
#
#      Inequality        Unit  Value
# 1526      Total  Percentage   80.0

# %%
CalidadEducativa['Value'].plot(kind='line')
plt.xlabel('paises')
plt.ylabel('Calidad educativa')
plt.title('Porcentaje de Calidad educativa en cada país')
plt.show()
